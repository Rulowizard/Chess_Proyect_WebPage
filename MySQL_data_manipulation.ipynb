# %%
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import pandas as pd

# %%
engine = create_engine ("mysql://root:Aa1$0110m@localhost/chess_db")

# %%
conn = engine.connect()
df = pd.read_sql("Select * FROM plays",conn)
df = df.drop( ["x_axis","y_axis"] , axis=1)
#Dataframe depurado
df.head()
# Out:
#    id  mov_len  end_game  game_len playerplays_type  depth winner  \
# 0   1       20         0         1               M1      0
# 1   2       20         0         2               M1      0
# 2   3       22         0         3               M1      0
# 3   4       27         0         4               M1      0
# 4   5       23         0         5               M1      0
#
#   end_game_mode
# 0
# 1
# 2
# 3
# 4

# %%
#DF que sólo contiene la info de las partidas acabadas
tabla_fin_partida = df.loc[ df["winner"] != ""  ]
tabla_fin_partida.head()
# Out:
#       id  mov_len  end_game  game_len playerplays_type  depth  winner  \
# 384  385       22         1       385               M1      0  Empate
# 421  422       45         1        37               M2      0  Blanco
# 532  533       42         1       111               M3      0  Blanco
# 583  584       54         1        51               M4      0  Blanco
# 646  647       56         1        63               M5      0  Blanco
#
#     end_game_mode
# 384         claim
# 421     checkmate
# 532     checkmate
# 583     checkmate
# 646     checkmate

# %%
total_movimientos= df["id"].max()
total_movimientos
# Out:
# 49272

# %%
total_posiciones_evaluadas = df["mov_len"].sum()
total_posiciones_evaluadas
# Out:
# 31210578

# %%
total_de_partidas = tabla_fin_partida["winner"].count()
total_de_partidas
# Out:
# 441

# %%
temp = tabla_fin_partida.loc[ tabla_fin_partida["end_game_mode"] == "checkmate" ]
clasif_jugadores = temp.groupby(["playerplays_type"])["winner"].count()
clasif_jugadores
# Out:
# playerplays_type
# M1      2
# M2      5
# M3     55
# M4     82
# M5    152
# Name: winner, dtype: int64

# %%
clasif_jugadores.index
# Out:
# Index(['M1', 'M2', 'M3', 'M4', 'M5'], dtype='object', name='playerplays_type')

# %%
mejor_jugador_name = clasif_jugadores.index[4]
mejor_jugador_score = clasif_jugadores[4]

# %%
peor_jugador_name = clasif_jugadores.index[0]
peor_jugador_score = clasif_jugadores[0]

# %%
list_dict = df.to_dict("records")

# %%
list_dict
# Out:
# [{'id': 1,
#   'mov_len': 20,
#   'end_game': 0,
#   'game_len': 1,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 2,
#   'mov_len': 20,
#   'end_game': 0,
#   'game_len': 2,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 3,
#   'mov_len': 22,
#   'end_game': 0,
#   'game_len': 3,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 4,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 4,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 5,
#   'mov_len': 23,
#   'end_game': 0,
#   'game_len': 5,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 6,
#   'mov_len': 28,
#   'end_game': 0,
#   'game_len': 6,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 7,
#   'mov_len': 21,
#   'end_game': 0,
#   'game_len': 7,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 8,
#   'mov_len': 29,
#   'end_game': 0,
#   'game_len': 8,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 9,
#   'mov_len': 22,
#   'end_game': 0,
#   'game_len': 9,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 10,
#   'mov_len': 31,
#   'end_game': 0,
#   'game_len': 10,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 11,
#   'mov_len': 23,
#   'end_game': 0,
#   'game_len': 11,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 12,
#   'mov_len': 30,
#   'end_game': 0,
#   'game_len': 12,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 13,
#   'mov_len': 22,
#   'end_game': 0,
#   'game_len': 13,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 14,
#   'mov_len': 30,
#   'end_game': 0,
#   'game_len': 14,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 15,
#   'mov_len': 22,
#   'end_game': 0,
#   'game_len': 15,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 16,
#   'mov_len': 28,
#   'end_game': 0,
#   'game_len': 16,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 17,
#   'mov_len': 23,
#   'end_game': 0,
#   'game_len': 17,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 18,
#   'mov_len': 31,
#   'end_game': 0,
#   'game_len': 18,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 19,
#   'mov_len': 23,
#   'end_game': 0,
#   'game_len': 19,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 20,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 20,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 21,
#   'mov_len': 21,
#   'end_game': 0,
#   'game_len': 21,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 22,
#   'mov_len': 31,
#   'end_game': 0,
#   'game_len': 22,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 23,
#   'mov_len': 24,
#   'end_game': 0,
#   'game_len': 23,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 24,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 24,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 25,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 25,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 26,
#   'mov_len': 30,
#   'end_game': 0,
#   'game_len': 26,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 27,
#   'mov_len': 31,
#   'end_game': 0,
#   'game_len': 27,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 28,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 28,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 29,
#   'mov_len': 29,
#   'end_game': 0,
#   'game_len': 29,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 30,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 30,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 31,
#   'mov_len': 31,
#   'end_game': 0,
#   'game_len': 31,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 32,
#   'mov_len': 33,
#   'end_game': 0,
#   'game_len': 32,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 33,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 33,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 34,
#   'mov_len': 26,
#   'end_game': 0,
#   'game_len': 34,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 35,
#   'mov_len': 30,
#   'end_game': 0,
#   'game_len': 35,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 36,
#   'mov_len': 25,
#   'end_game': 0,
#   'game_len': 36,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 37,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 37,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 38,
#   'mov_len': 26,
#   'end_game': 0,
#   'game_len': 38,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 39,
#   'mov_len': 25,
#   'end_game': 0,
#   'game_len': 39,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 40,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 40,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 41,
#   'mov_len': 24,
#   'end_game': 0,
#   'game_len': 41,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 42,
#   'mov_len': 26,
#   'end_game': 0,
#   'game_len': 42,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 43,
#   'mov_len': 25,
#   'end_game': 0,
#   'game_len': 43,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 44,
#   'mov_len': 31,
#   'end_game': 0,
#   'game_len': 44,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 45,
#   'mov_len': 20,
#   'end_game': 0,
#   'game_len': 45,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 46,
#   'mov_len': 33,
#   'end_game': 0,
#   'game_len': 46,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 47,
#   'mov_len': 21,
#   'end_game': 0,
#   'game_len': 47,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 48,
#   'mov_len': 33,
#   'end_game': 0,
#   'game_len': 48,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 49,
#   'mov_len': 22,
#   'end_game': 0,
#   'game_len': 49,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 50,
#   'mov_len': 33,
#   'end_game': 0,
#   'game_len': 50,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 51,
#   'mov_len': 30,
#   'end_game': 0,
#   'game_len': 51,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 52,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 52,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 53,
#   'mov_len': 30,
#   'end_game': 0,
#   'game_len': 53,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 54,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 54,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 55,
#   'mov_len': 29,
#   'end_game': 0,
#   'game_len': 55,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 56,
#   'mov_len': 36,
#   'end_game': 0,
#   'game_len': 56,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 57,
#   'mov_len': 28,
#   'end_game': 0,
#   'game_len': 57,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 58,
#   'mov_len': 36,
#   'end_game': 0,
#   'game_len': 58,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 59,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 59,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 60,
#   'mov_len': 36,
#   'end_game': 0,
#   'game_len': 60,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 61,
#   'mov_len': 23,
#   'end_game': 0,
#   'game_len': 61,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 62,
#   'mov_len': 33,
#   'end_game': 0,
#   'game_len': 62,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 63,
#   'mov_len': 25,
#   'end_game': 0,
#   'game_len': 63,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 64,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 64,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 65,
#   'mov_len': 26,
#   'end_game': 0,
#   'game_len': 65,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 66,
#   'mov_len': 36,
#   'end_game': 0,
#   'game_len': 66,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 67,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 67,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 68,
#   'mov_len': 41,
#   'end_game': 0,
#   'game_len': 68,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 69,
#   'mov_len': 33,
#   'end_game': 0,
#   'game_len': 69,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 70,
#   'mov_len': 42,
#   'end_game': 0,
#   'game_len': 70,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 71,
#   'mov_len': 37,
#   'end_game': 0,
#   'game_len': 71,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 72,
#   'mov_len': 7,
#   'end_game': 0,
#   'game_len': 72,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 73,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 73,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 74,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 74,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 75,
#   'mov_len': 34,
#   'end_game': 0,
#   'game_len': 75,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 76,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 76,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 77,
#   'mov_len': 48,
#   'end_game': 0,
#   'game_len': 77,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 78,
#   'mov_len': 36,
#   'end_game': 0,
#   'game_len': 78,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 79,
#   'mov_len': 41,
#   'end_game': 0,
#   'game_len': 79,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 80,
#   'mov_len': 34,
#   'end_game': 0,
#   'game_len': 80,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 81,
#   'mov_len': 40,
#   'end_game': 0,
#   'game_len': 81,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 82,
#   'mov_len': 39,
#   'end_game': 0,
#   'game_len': 82,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 83,
#   'mov_len': 39,
#   'end_game': 0,
#   'game_len': 83,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 84,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 84,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 85,
#   'mov_len': 40,
#   'end_game': 0,
#   'game_len': 85,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 86,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 86,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 87,
#   'mov_len': 39,
#   'end_game': 0,
#   'game_len': 87,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 88,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 88,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 89,
#   'mov_len': 34,
#   'end_game': 0,
#   'game_len': 89,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 90,
#   'mov_len': 30,
#   'end_game': 0,
#   'game_len': 90,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 91,
#   'mov_len': 6,
#   'end_game': 0,
#   'game_len': 91,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 92,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 92,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 93,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 93,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 94,
#   'mov_len': 36,
#   'end_game': 0,
#   'game_len': 94,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 95,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 95,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 96,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 96,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 97,
#   'mov_len': 38,
#   'end_game': 0,
#   'game_len': 97,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 98,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 98,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 99,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 99,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 100,
#   'mov_len': 30,
#   'end_game': 0,
#   'game_len': 100,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 101,
#   'mov_len': 33,
#   'end_game': 0,
#   'game_len': 101,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 102,
#   'mov_len': 28,
#   'end_game': 0,
#   'game_len': 102,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 103,
#   'mov_len': 34,
#   'end_game': 0,
#   'game_len': 103,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 104,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 104,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 105,
#   'mov_len': 36,
#   'end_game': 0,
#   'game_len': 105,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 106,
#   'mov_len': 30,
#   'end_game': 0,
#   'game_len': 106,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 107,
#   'mov_len': 40,
#   'end_game': 0,
#   'game_len': 107,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 108,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 108,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 109,
#   'mov_len': 39,
#   'end_game': 0,
#   'game_len': 109,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 110,
#   'mov_len': 26,
#   'end_game': 0,
#   'game_len': 110,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 111,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 111,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 112,
#   'mov_len': 30,
#   'end_game': 0,
#   'game_len': 112,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 113,
#   'mov_len': 39,
#   'end_game': 0,
#   'game_len': 113,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 114,
#   'mov_len': 24,
#   'end_game': 0,
#   'game_len': 114,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 115,
#   'mov_len': 36,
#   'end_game': 0,
#   'game_len': 115,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 116,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 116,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 117,
#   'mov_len': 39,
#   'end_game': 0,
#   'game_len': 117,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 118,
#   'mov_len': 23,
#   'end_game': 0,
#   'game_len': 118,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 119,
#   'mov_len': 40,
#   'end_game': 0,
#   'game_len': 119,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 120,
#   'mov_len': 23,
#   'end_game': 0,
#   'game_len': 120,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 121,
#   'mov_len': 37,
#   'end_game': 0,
#   'game_len': 121,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 122,
#   'mov_len': 23,
#   'end_game': 0,
#   'game_len': 122,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 123,
#   'mov_len': 45,
#   'end_game': 0,
#   'game_len': 123,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 124,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 124,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 125,
#   'mov_len': 47,
#   'end_game': 0,
#   'game_len': 125,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 126,
#   'mov_len': 21,
#   'end_game': 0,
#   'game_len': 126,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 127,
#   'mov_len': 48,
#   'end_game': 0,
#   'game_len': 127,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 128,
#   'mov_len': 24,
#   'end_game': 0,
#   'game_len': 128,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 129,
#   'mov_len': 44,
#   'end_game': 0,
#   'game_len': 129,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 130,
#   'mov_len': 15,
#   'end_game': 0,
#   'game_len': 130,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 131,
#   'mov_len': 49,
#   'end_game': 0,
#   'game_len': 131,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 132,
#   'mov_len': 12,
#   'end_game': 0,
#   'game_len': 132,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 133,
#   'mov_len': 45,
#   'end_game': 0,
#   'game_len': 133,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 134,
#   'mov_len': 16,
#   'end_game': 0,
#   'game_len': 134,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 135,
#   'mov_len': 41,
#   'end_game': 0,
#   'game_len': 135,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 136,
#   'mov_len': 21,
#   'end_game': 0,
#   'game_len': 136,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 137,
#   'mov_len': 45,
#   'end_game': 0,
#   'game_len': 137,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 138,
#   'mov_len': 20,
#   'end_game': 0,
#   'game_len': 138,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 139,
#   'mov_len': 49,
#   'end_game': 0,
#   'game_len': 139,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 140,
#   'mov_len': 18,
#   'end_game': 0,
#   'game_len': 140,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 141,
#   'mov_len': 52,
#   'end_game': 0,
#   'game_len': 141,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 142,
#   'mov_len': 15,
#   'end_game': 0,
#   'game_len': 142,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 143,
#   'mov_len': 49,
#   'end_game': 0,
#   'game_len': 143,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 144,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 144,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 145,
#   'mov_len': 42,
#   'end_game': 0,
#   'game_len': 145,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 146,
#   'mov_len': 17,
#   'end_game': 0,
#   'game_len': 146,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 147,
#   'mov_len': 57,
#   'end_game': 0,
#   'game_len': 147,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 148,
#   'mov_len': 15,
#   'end_game': 0,
#   'game_len': 148,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 149,
#   'mov_len': 52,
#   'end_game': 0,
#   'game_len': 149,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 150,
#   'mov_len': 15,
#   'end_game': 0,
#   'game_len': 150,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 151,
#   'mov_len': 46,
#   'end_game': 0,
#   'game_len': 151,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 152,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 152,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 153,
#   'mov_len': 58,
#   'end_game': 0,
#   'game_len': 153,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 154,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 154,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 155,
#   'mov_len': 47,
#   'end_game': 0,
#   'game_len': 155,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 156,
#   'mov_len': 28,
#   'end_game': 0,
#   'game_len': 156,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 157,
#   'mov_len': 39,
#   'end_game': 0,
#   'game_len': 157,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 158,
#   'mov_len': 31,
#   'end_game': 0,
#   'game_len': 158,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 159,
#   'mov_len': 49,
#   'end_game': 0,
#   'game_len': 159,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 160,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 160,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 161,
#   'mov_len': 56,
#   'end_game': 0,
#   'game_len': 161,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 162,
#   'mov_len': 5,
#   'end_game': 0,
#   'game_len': 162,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 163,
#   'mov_len': 52,
#   'end_game': 0,
#   'game_len': 163,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 164,
#   'mov_len': 30,
#   'end_game': 0,
#   'game_len': 164,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 165,
#   'mov_len': 44,
#   'end_game': 0,
#   'game_len': 165,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 166,
#   'mov_len': 33,
#   'end_game': 0,
#   'game_len': 166,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 167,
#   'mov_len': 42,
#   'end_game': 0,
#   'game_len': 167,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 168,
#   'mov_len': 33,
#   'end_game': 0,
#   'game_len': 168,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 169,
#   'mov_len': 34,
#   'end_game': 0,
#   'game_len': 169,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 170,
#   'mov_len': 24,
#   'end_game': 0,
#   'game_len': 170,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 171,
#   'mov_len': 43,
#   'end_game': 0,
#   'game_len': 171,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 172,
#   'mov_len': 31,
#   'end_game': 0,
#   'game_len': 172,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 173,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 173,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 174,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 174,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 175,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 175,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 176,
#   'mov_len': 34,
#   'end_game': 0,
#   'game_len': 176,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 177,
#   'mov_len': 4,
#   'end_game': 0,
#   'game_len': 177,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 178,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 178,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 179,
#   'mov_len': 29,
#   'end_game': 0,
#   'game_len': 179,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 180,
#   'mov_len': 20,
#   'end_game': 0,
#   'game_len': 180,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 181,
#   'mov_len': 26,
#   'end_game': 0,
#   'game_len': 181,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 182,
#   'mov_len': 24,
#   'end_game': 0,
#   'game_len': 182,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 183,
#   'mov_len': 29,
#   'end_game': 0,
#   'game_len': 183,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 184,
#   'mov_len': 20,
#   'end_game': 0,
#   'game_len': 184,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 185,
#   'mov_len': 28,
#   'end_game': 0,
#   'game_len': 185,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 186,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 186,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 187,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 187,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 188,
#   'mov_len': 21,
#   'end_game': 0,
#   'game_len': 188,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 189,
#   'mov_len': 48,
#   'end_game': 0,
#   'game_len': 189,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 190,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 190,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 191,
#   'mov_len': 40,
#   'end_game': 0,
#   'game_len': 191,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 192,
#   'mov_len': 15,
#   'end_game': 0,
#   'game_len': 192,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 193,
#   'mov_len': 44,
#   'end_game': 0,
#   'game_len': 193,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 194,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 194,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 195,
#   'mov_len': 44,
#   'end_game': 0,
#   'game_len': 195,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 196,
#   'mov_len': 15,
#   'end_game': 0,
#   'game_len': 196,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 197,
#   'mov_len': 46,
#   'end_game': 0,
#   'game_len': 197,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 198,
#   'mov_len': 18,
#   'end_game': 0,
#   'game_len': 198,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 199,
#   'mov_len': 44,
#   'end_game': 0,
#   'game_len': 199,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 200,
#   'mov_len': 28,
#   'end_game': 0,
#   'game_len': 200,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 201,
#   'mov_len': 49,
#   'end_game': 0,
#   'game_len': 201,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 202,
#   'mov_len': 28,
#   'end_game': 0,
#   'game_len': 202,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 203,
#   'mov_len': 45,
#   'end_game': 0,
#   'game_len': 203,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 204,
#   'mov_len': 25,
#   'end_game': 0,
#   'game_len': 204,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 205,
#   'mov_len': 47,
#   'end_game': 0,
#   'game_len': 205,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 206,
#   'mov_len': 25,
#   'end_game': 0,
#   'game_len': 206,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 207,
#   'mov_len': 43,
#   'end_game': 0,
#   'game_len': 207,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 208,
#   'mov_len': 23,
#   'end_game': 0,
#   'game_len': 208,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 209,
#   'mov_len': 50,
#   'end_game': 0,
#   'game_len': 209,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 210,
#   'mov_len': 24,
#   'end_game': 0,
#   'game_len': 210,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 211,
#   'mov_len': 45,
#   'end_game': 0,
#   'game_len': 211,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 212,
#   'mov_len': 26,
#   'end_game': 0,
#   'game_len': 212,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 213,
#   'mov_len': 46,
#   'end_game': 0,
#   'game_len': 213,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 214,
#   'mov_len': 18,
#   'end_game': 0,
#   'game_len': 214,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 215,
#   'mov_len': 44,
#   'end_game': 0,
#   'game_len': 215,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 216,
#   'mov_len': 18,
#   'end_game': 0,
#   'game_len': 216,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 217,
#   'mov_len': 47,
#   'end_game': 0,
#   'game_len': 217,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 218,
#   'mov_len': 22,
#   'end_game': 0,
#   'game_len': 218,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 219,
#   'mov_len': 49,
#   'end_game': 0,
#   'game_len': 219,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 220,
#   'mov_len': 22,
#   'end_game': 0,
#   'game_len': 220,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 221,
#   'mov_len': 49,
#   'end_game': 0,
#   'game_len': 221,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 222,
#   'mov_len': 23,
#   'end_game': 0,
#   'game_len': 222,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 223,
#   'mov_len': 49,
#   'end_game': 0,
#   'game_len': 223,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 224,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 224,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 225,
#   'mov_len': 29,
#   'end_game': 0,
#   'game_len': 225,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 226,
#   'mov_len': 21,
#   'end_game': 0,
#   'game_len': 226,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 227,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 227,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 228,
#   'mov_len': 23,
#   'end_game': 0,
#   'game_len': 228,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 229,
#   'mov_len': 31,
#   'end_game': 0,
#   'game_len': 229,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 230,
#   'mov_len': 25,
#   'end_game': 0,
#   'game_len': 230,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 231,
#   'mov_len': 29,
#   'end_game': 0,
#   'game_len': 231,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 232,
#   'mov_len': 20,
#   'end_game': 0,
#   'game_len': 232,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 233,
#   'mov_len': 27,
#   'end_game': 0,
#   'game_len': 233,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 234,
#   'mov_len': 4,
#   'end_game': 0,
#   'game_len': 234,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 235,
#   'mov_len': 31,
#   'end_game': 0,
#   'game_len': 235,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 236,
#   'mov_len': 16,
#   'end_game': 0,
#   'game_len': 236,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 237,
#   'mov_len': 26,
#   'end_game': 0,
#   'game_len': 237,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 238,
#   'mov_len': 18,
#   'end_game': 0,
#   'game_len': 238,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 239,
#   'mov_len': 28,
#   'end_game': 0,
#   'game_len': 239,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 240,
#   'mov_len': 21,
#   'end_game': 0,
#   'game_len': 240,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 241,
#   'mov_len': 30,
#   'end_game': 0,
#   'game_len': 241,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 242,
#   'mov_len': 20,
#   'end_game': 0,
#   'game_len': 242,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 243,
#   'mov_len': 28,
#   'end_game': 0,
#   'game_len': 243,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 244,
#   'mov_len': 18,
#   'end_game': 0,
#   'game_len': 244,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 245,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 245,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 246,
#   'mov_len': 16,
#   'end_game': 0,
#   'game_len': 246,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 247,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 247,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 248,
#   'mov_len': 15,
#   'end_game': 0,
#   'game_len': 248,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 249,
#   'mov_len': 25,
#   'end_game': 0,
#   'game_len': 249,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 250,
#   'mov_len': 17,
#   'end_game': 0,
#   'game_len': 250,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 251,
#   'mov_len': 17,
#   'end_game': 0,
#   'game_len': 251,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 252,
#   'mov_len': 5,
#   'end_game': 0,
#   'game_len': 252,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 253,
#   'mov_len': 21,
#   'end_game': 0,
#   'game_len': 253,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 254,
#   'mov_len': 16,
#   'end_game': 0,
#   'game_len': 254,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 255,
#   'mov_len': 23,
#   'end_game': 0,
#   'game_len': 255,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 256,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 256,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 257,
#   'mov_len': 21,
#   'end_game': 0,
#   'game_len': 257,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 258,
#   'mov_len': 18,
#   'end_game': 0,
#   'game_len': 258,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 259,
#   'mov_len': 21,
#   'end_game': 0,
#   'game_len': 259,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 260,
#   'mov_len': 20,
#   'end_game': 0,
#   'game_len': 260,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 261,
#   'mov_len': 21,
#   'end_game': 0,
#   'game_len': 261,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 262,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 262,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 263,
#   'mov_len': 16,
#   'end_game': 0,
#   'game_len': 263,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 264,
#   'mov_len': 22,
#   'end_game': 0,
#   'game_len': 264,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 265,
#   'mov_len': 16,
#   'end_game': 0,
#   'game_len': 265,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 266,
#   'mov_len': 15,
#   'end_game': 0,
#   'game_len': 266,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 267,
#   'mov_len': 16,
#   'end_game': 0,
#   'game_len': 267,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 268,
#   'mov_len': 25,
#   'end_game': 0,
#   'game_len': 268,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 269,
#   'mov_len': 16,
#   'end_game': 0,
#   'game_len': 269,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 270,
#   'mov_len': 9,
#   'end_game': 0,
#   'game_len': 270,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 271,
#   'mov_len': 21,
#   'end_game': 0,
#   'game_len': 271,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 272,
#   'mov_len': 12,
#   'end_game': 0,
#   'game_len': 272,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 273,
#   'mov_len': 14,
#   'end_game': 0,
#   'game_len': 273,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 274,
#   'mov_len': 29,
#   'end_game': 0,
#   'game_len': 274,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 275,
#   'mov_len': 17,
#   'end_game': 0,
#   'game_len': 275,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 276,
#   'mov_len': 29,
#   'end_game': 0,
#   'game_len': 276,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 277,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 277,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 278,
#   'mov_len': 26,
#   'end_game': 0,
#   'game_len': 278,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 279,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 279,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 280,
#   'mov_len': 29,
#   'end_game': 0,
#   'game_len': 280,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 281,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 281,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 282,
#   'mov_len': 29,
#   'end_game': 0,
#   'game_len': 282,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 283,
#   'mov_len': 17,
#   'end_game': 0,
#   'game_len': 283,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 284,
#   'mov_len': 29,
#   'end_game': 0,
#   'game_len': 284,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 285,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 285,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 286,
#   'mov_len': 8,
#   'end_game': 0,
#   'game_len': 286,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 287,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 287,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 288,
#   'mov_len': 5,
#   'end_game': 0,
#   'game_len': 288,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 289,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 289,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 290,
#   'mov_len': 5,
#   'end_game': 0,
#   'game_len': 290,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 291,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 291,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 292,
#   'mov_len': 8,
#   'end_game': 0,
#   'game_len': 292,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 293,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 293,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 294,
#   'mov_len': 5,
#   'end_game': 0,
#   'game_len': 294,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 295,
#   'mov_len': 18,
#   'end_game': 0,
#   'game_len': 295,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 296,
#   'mov_len': 5,
#   'end_game': 0,
#   'game_len': 296,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 297,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 297,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 298,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 298,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 299,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 299,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 300,
#   'mov_len': 8,
#   'end_game': 0,
#   'game_len': 300,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 301,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 301,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 302,
#   'mov_len': 5,
#   'end_game': 0,
#   'game_len': 302,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 303,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 303,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 304,
#   'mov_len': 5,
#   'end_game': 0,
#   'game_len': 304,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 305,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 305,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 306,
#   'mov_len': 8,
#   'end_game': 0,
#   'game_len': 306,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 307,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 307,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 308,
#   'mov_len': 5,
#   'end_game': 0,
#   'game_len': 308,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 309,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 309,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 310,
#   'mov_len': 5,
#   'end_game': 0,
#   'game_len': 310,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 311,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 311,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 312,
#   'mov_len': 8,
#   'end_game': 0,
#   'game_len': 312,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 313,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 313,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 314,
#   'mov_len': 8,
#   'end_game': 0,
#   'game_len': 314,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 315,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 315,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 316,
#   'mov_len': 8,
#   'end_game': 0,
#   'game_len': 316,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 317,
#   'mov_len': 16,
#   'end_game': 0,
#   'game_len': 317,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 318,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 318,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 319,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 319,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 320,
#   'mov_len': 4,
#   'end_game': 0,
#   'game_len': 320,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 321,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 321,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 322,
#   'mov_len': 8,
#   'end_game': 0,
#   'game_len': 322,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 323,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 323,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 324,
#   'mov_len': 8,
#   'end_game': 0,
#   'game_len': 324,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 325,
#   'mov_len': 19,
#   'end_game': 0,
#   'game_len': 325,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 326,
#   'mov_len': 5,
#   'end_game': 0,
#   'game_len': 326,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
# ...
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 893,
#   'mov_len': 25,
#   'end_game': 0,
#   'game_len': 148,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 894,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 149,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 895,
#   'mov_len': 29,
#   'end_game': 0,
#   'game_len': 150,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 896,
#   'mov_len': 1,
#   'end_game': 0,
#   'game_len': 151,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 897,
#   'mov_len': 26,
#   'end_game': 0,
#   'game_len': 152,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 898,
#   'mov_len': 4,
#   'end_game': 0,
#   'game_len': 153,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 899,
#   'mov_len': 32,
#   'end_game': 0,
#   'game_len': 154,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 900,
#   'mov_len': 7,
#   'end_game': 0,
#   'game_len': 155,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 901,
#   'mov_len': 28,
#   'end_game': 0,
#   'game_len': 156,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 902,
#   'mov_len': 5,
#   'end_game': 0,
#   'game_len': 157,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 903,
#   'mov_len': 28,
#   'end_game': 0,
#   'game_len': 158,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 904,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 159,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 905,
#   'mov_len': 31,
#   'end_game': 0,
#   'game_len': 160,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 906,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 161,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 907,
#   'mov_len': 43,
#   'end_game': 0,
#   'game_len': 162,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 908,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 163,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 909,
#   'mov_len': 49,
#   'end_game': 0,
#   'game_len': 164,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 910,
#   'mov_len': 1,
#   'end_game': 0,
#   'game_len': 165,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 911,
#   'mov_len': 54,
#   'end_game': 0,
#   'game_len': 166,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 912,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 167,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 913,
#   'mov_len': 49,
#   'end_game': 0,
#   'game_len': 168,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 914,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 169,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 915,
#   'mov_len': 47,
#   'end_game': 0,
#   'game_len': 170,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 916,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 171,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 917,
#   'mov_len': 52,
#   'end_game': 0,
#   'game_len': 172,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 918,
#   'mov_len': 4,
#   'end_game': 0,
#   'game_len': 173,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 919,
#   'mov_len': 40,
#   'end_game': 0,
#   'game_len': 174,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 920,
#   'mov_len': 7,
#   'end_game': 0,
#   'game_len': 175,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 921,
#   'mov_len': 38,
#   'end_game': 0,
#   'game_len': 176,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 922,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 177,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 923,
#   'mov_len': 43,
#   'end_game': 0,
#   'game_len': 178,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 924,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 179,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 925,
#   'mov_len': 43,
#   'end_game': 0,
#   'game_len': 180,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 926,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 181,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 927,
#   'mov_len': 45,
#   'end_game': 0,
#   'game_len': 182,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 928,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 183,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 929,
#   'mov_len': 44,
#   'end_game': 0,
#   'game_len': 184,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 930,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 185,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 931,
#   'mov_len': 47,
#   'end_game': 0,
#   'game_len': 186,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 932,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 187,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 933,
#   'mov_len': 49,
#   'end_game': 0,
#   'game_len': 188,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 934,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 189,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 935,
#   'mov_len': 50,
#   'end_game': 0,
#   'game_len': 190,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 936,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 191,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 937,
#   'mov_len': 46,
#   'end_game': 0,
#   'game_len': 192,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 938,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 193,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 939,
#   'mov_len': 42,
#   'end_game': 0,
#   'game_len': 194,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 940,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 195,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 941,
#   'mov_len': 39,
#   'end_game': 0,
#   'game_len': 196,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 942,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 197,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 943,
#   'mov_len': 40,
#   'end_game': 0,
#   'game_len': 198,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 944,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 199,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 945,
#   'mov_len': 40,
#   'end_game': 0,
#   'game_len': 200,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 946,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 201,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 947,
#   'mov_len': 37,
#   'end_game': 0,
#   'game_len': 202,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 948,
#   'mov_len': 4,
#   'end_game': 0,
#   'game_len': 203,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 949,
#   'mov_len': 35,
#   'end_game': 0,
#   'game_len': 204,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 950,
#   'mov_len': 6,
#   'end_game': 0,
#   'game_len': 205,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 951,
#   'mov_len': 33,
#   'end_game': 0,
#   'game_len': 206,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 952,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 207,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 953,
#   'mov_len': 31,
#   'end_game': 0,
#   'game_len': 208,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 954,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 209,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 955,
#   'mov_len': 42,
#   'end_game': 0,
#   'game_len': 210,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 956,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 211,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 957,
#   'mov_len': 37,
#   'end_game': 0,
#   'game_len': 212,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 958,
#   'mov_len': 5,
#   'end_game': 0,
#   'game_len': 213,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 959,
#   'mov_len': 41,
#   'end_game': 0,
#   'game_len': 214,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 960,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 215,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 961,
#   'mov_len': 43,
#   'end_game': 0,
#   'game_len': 216,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 962,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 217,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 963,
#   'mov_len': 39,
#   'end_game': 0,
#   'game_len': 218,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 964,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 219,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 965,
#   'mov_len': 41,
#   'end_game': 0,
#   'game_len': 220,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 966,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 221,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 967,
#   'mov_len': 41,
#   'end_game': 0,
#   'game_len': 222,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 968,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 223,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 969,
#   'mov_len': 40,
#   'end_game': 0,
#   'game_len': 224,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 970,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 225,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 971,
#   'mov_len': 39,
#   'end_game': 0,
#   'game_len': 226,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 972,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 227,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 973,
#   'mov_len': 45,
#   'end_game': 0,
#   'game_len': 228,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 974,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 229,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 975,
#   'mov_len': 46,
#   'end_game': 0,
#   'game_len': 230,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 976,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 231,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 977,
#   'mov_len': 43,
#   'end_game': 0,
#   'game_len': 232,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 978,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 233,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 979,
#   'mov_len': 44,
#   'end_game': 0,
#   'game_len': 234,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 980,
#   'mov_len': 1,
#   'end_game': 0,
#   'game_len': 235,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 981,
#   'mov_len': 42,
#   'end_game': 0,
#   'game_len': 236,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 982,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 237,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 983,
#   'mov_len': 41,
#   'end_game': 0,
#   'game_len': 238,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 984,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 239,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 985,
#   'mov_len': 44,
#   'end_game': 0,
#   'game_len': 240,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 986,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 241,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 987,
#   'mov_len': 41,
#   'end_game': 0,
#   'game_len': 242,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 988,
#   'mov_len': 2,
#   'end_game': 0,
#   'game_len': 243,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 989,
#   'mov_len': 41,
#   'end_game': 0,
#   'game_len': 244,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 990,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 245,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 991,
#   'mov_len': 40,
#   'end_game': 0,
#   'game_len': 246,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 992,
#   'mov_len': 4,
#   'end_game': 0,
#   'game_len': 247,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 993,
#   'mov_len': 41,
#   'end_game': 0,
#   'game_len': 248,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 994,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 249,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 995,
#   'mov_len': 43,
#   'end_game': 0,
#   'game_len': 250,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 996,
#   'mov_len': 4,
#   'end_game': 0,
#   'game_len': 251,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 997,
#   'mov_len': 43,
#   'end_game': 0,
#   'game_len': 252,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 998,
#   'mov_len': 3,
#   'end_game': 0,
#   'game_len': 253,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 999,
#   'mov_len': 42,
#   'end_game': 0,
#   'game_len': 254,
#   'playerplays_type': 'M2',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  {'id': 1000,
#   'mov_len': 4,
#   'end_game': 0,
#   'game_len': 255,
#   'playerplays_type': 'M1',
#   'depth': 0,
#   'winner': '',
#   'end_game_mode': ''},
#  ...]
